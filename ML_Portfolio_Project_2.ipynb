# %% [markdown]
# <a href="https://colab.research.google.com/github/Arunkumar-sahu/Portfolio_project/blob/main/ML_Portfolio_Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as ply
import seaborn as snr

# %%
data=pd.read_csv('/content/train_dataset.csv')

# %%
data.head()
# Out:
#    Age  Flight Distance  Inflight wifi service  \
# 0   35              971                      3
# 1   32             1092                      0
# 2   46             2915                      0
# 3   56             2556                      4
# 4   54              468                      1
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                                  4                       5              4
# 1                                  0                       0              3
# 2                                  5                       0              5
# 3                                  4                       4              4
# 4                                  4                       1              4
#
#    Food and drink  Online boarding  Seat comfort  Inflight entertainment  ...  \
# 0               2                3             3                       2  ...
# ...

# %%
data['satisfaction']=data['satisfaction'].apply({'satisfied':1,'neutral or dissatisfied':0}.get)

# %%
data.head(15)
# Out:
#     Age  Flight Distance  Inflight wifi service  \
# 0    35              971                      3
# 1    32             1092                      0
# 2    46             2915                      0
# 3    56             2556                      4
# 4    54              468                      1
# 5    17             1754                      1
# 6    21              770                      1
# 7    22              752                      3
# 8    33              200                      2
# 9     9              948                      1
# 10   42             1812                      5
# 11   29             1306                      3
# 12   37             3409                      3
# 13   28              950                      3
# 14   18             2057                      2
#
#     Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                                   4                       5              4
# ...

# %% [markdown]
# Considering the first 15 passengers, compute how many of them were satisfied with the airline services after taking a business travel

# %%
d= ['purple','grey','brown','green','yellow','red']

# %%
data.iloc[0:15].plot(x='Type of Travel_Business travel',y='satisfaction',kind='bar',color=d)
# Out:
# <Axes: xlabel='Type of Travel_Business travel'>

# %% [markdown]
# Creating a pie chart derive the contributions of 'Food and drink', 'Online boarding', 'Seat comfort' and 'Inflight entertainment' features in providing satisfactory services for the first 5 passengers from the aviation industry.

# %%
new_data=data.iloc[:,6:10]

# %%
new_data.iloc[0:5].plot.pie(subplots=True,figsize=(15,15),fontsize=10,autopct='%.2f')
# Out:
# array([<Axes: ylabel='Food and drink'>, <Axes: ylabel='Online boarding'>,
#        <Axes: ylabel='Seat comfort'>,
#        <Axes: ylabel='Inflight entertainment'>], dtype=object)

# %% [markdown]
#  Nowadays e-ticket or online flight tickets have replaced the print ones. Passengers and airline company makes a contract through e-tickets. In this context derive intuition from the dataset for the first 20 passengers as to how age, gender and class of flight(business/economy) are related.
#
# It will help you to understand which age group of passengers boarding which class of flight are more comfortable in booking tickets online

# %%
my_data=data.iloc[0:20]

# %%
snr.relplot(y='Ease of Online booking',x='Age',hue='Gender_Female',col='Class_Business',data=my_data)

# %%
x=data.drop(['satisfaction'],axis=1)
y=data['satisfaction']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8)

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
log_model=LogisticRegression()

# %%
log_model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predictions=log_model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm=confusion_matrix(y_test,predictions)
ac=accuracy_score(y_test,predictions)

# %%
print(cm)
# Out:
# [[4732 1004]
#  [ 805 3612]]

# %%
print(ac)
# Out:
# 0.821826061262681

# %%
data_new={'Age':26,'Flight Distance':696,'Inflight wifi service':1,'Departure/Arrival time convenient':3,'Ease of Online booking':2,'Gate location':4,'Food and drink':2,'Online boarding':0,'Seat comfort':3,'Inflight entertainment':1,'On-board service':2,'Leg room service':2,'Baggage handling':3,'Checkin service':3,'Inflight service':3,'Cleanliness':3,'Departure Delay in Minutes':20,'Arrival Delay in Minutes':32,'Gender_Female':0,'Gender_Male':1,'Type of Travel_Business travel':1,'Type of Travel_Personal Travel':0,'Class_Business':1,'Class_Eco':0,'Class_Eco Plus':1}

# %%
index=[1]
my_data=pd.DataFrame(data_new,index)

# %%
my_data
# Out:
#    Age  Flight Distance  Inflight wifi service  \
# 1   26              696                      1
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 1                                  3                       2              4
#
#    Food and drink  Online boarding  Seat comfort  Inflight entertainment  ...  \
# 1               2                0             3                       1  ...
#
#    Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 1            3                          20                        32
#
#    Gender_Female  Gender_Male  Type of Travel_Business travel  \
# 1              0            1                               1
#
#    Type of Travel_Personal Travel  Class_Business  Class_Eco  Class_Eco Plus
# 1                               0               1          0               1
#
# [1 rows x 25 columns]

# %%
new_predictions=log_model.predict(my_data)

if new_predictions==1:
 print('The passenger will be satisfied')

else:
  print('The passenger will be neutral or dissatisfied')
# Out:
# The passenger will be neutral or dissatisfied
